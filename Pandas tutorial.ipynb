# %%
import pandas as pd

# %%
colors = pd.Series(["red","blue","green","black"])

# %%
colors
# Out:
# 0      red
# 1     blue
# 2    green
# 3    black
# dtype: object

# %%
car_type = pd.Series(["BMW","Honda","Audi"])

# %%
cars =pd.DataFrame({"car_make" : car_type , "color" : colors})

# %%
cars
# Out:
#   car_make  color
# 0      BMW    red
# 1    Honda   blue
# 2     Audi  green
# 3      NaN  black

# %%
car_sale = pd.read_csv("car-sales.csv")

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported-cars")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 car_sales.to_csv("exported-cars")
#
# NameError: name 'car_sales' is not defined

# %%
car_sale.to_csv("exported-cars.csv",index=False)

# %%
exported_sales=pd.read_csv("exported-cars.csv")

# %%
exported_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sale.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# #loc and iloc

# %%
animals=pd.Series(["cat","dog","lion","tiger","whale"], index = [0,3,5,7,3])
#setting user defined indices

# %%
animals[3]
# Out:
# 3      dog
# 3    whale
# dtype: object

# %% [markdown]
# RETURNED A LIST AND HENCE WE SEE INDEX AND DATA TYPE MENTIONED FOR BOTH OBJECTS. NOW WE COMPARE WITH DATA WHICH DOES NPT HAVE DULPICATE

# %%
animals[5]
# Out:
# 'lion'

# %% [markdown]
# Now we are only getting a value

# %%
car_sale.loc[2]
# Out:
# Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
animals.iloc[3]
# Out:
# 'tiger'

# %%
car_sale["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sale[car_sale["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sale["Make"],car_sale["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
car_sale.groupby("Make").agg('min')
# Out:
#        Colour  Odometer (KM)  Doors       Price
# Make
# BMW     Black          11179      5  $22,000.00
# Honda    Blue          45698      4   $5,000.00
# Nissan  White          31600      4   $3,500.00
# Toyota   Blue          32549      3   $4,000.00

# %%
car_sale["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sale.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#car_sale["Price"]=car_sale["Price"].str.rstrip('00')
#car_sale["Price"]=car_sale["Price"].str.replace('[\$\.\,]','',regex=True).astype(int)
car_sale['Price'].floordiv(100)
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000

# %%
car_sale.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000

# %%
car_sale['Price']=car_sale['Price'].floordiv(100)

# %%
car_sale.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
car_sale["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna("Null",inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue      Null    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green      Null    4.0   $4,500
# 6   Honda    NaN      Null    4.0   $7,500
# 7   Honda   Blue      Null    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].replace(("Null","NaN"),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   87899.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green  213095.0    4.0   $4,500
# 6   Honda    NaN  213095.0    4.0   $7,500
# 7   Honda   Blue  213095.0    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped=car_sales_missing.dropna()

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv')

# %%
#COLUMN FROM PANDAS SERIES
seats_col=pd.Series([5,6,7,4,4,5])

# %%
car_sale["seats"]=seats_col

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    6.0
# 2  Toyota   Blue          32549      3   $7,000.00    7.0
# 3     BMW  Black          11179      5  $22,000.00    4.0
# 4  Nissan  White         213095      4   $3,500.00    4.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sale['seats'].fillna(5,inplace=True)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    6.0
# 2  Toyota   Blue          32549      3   $7,000.00    7.0
# 3     BMW  Black          11179      5  $22,000.00    4.0
# 4  Nissan  White         213095      4   $3,500.00    4.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
#COLUMN FROM PYTHON LIST - INDEX MUST BE SAME AS NUMBER OF ROWS
fuel_eco=[5.6,7.9,8.9,7, 9, 6, 7.8,9.9,10,9]
car_sale["Fuel per 100 km"]=fuel_eco

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuel per 100 km
# 0  Toyota  White         150043      4   $4,000.00    5.0              5.6
# 1   Honda    Red          87899      4   $5,000.00    6.0              7.9
# 2  Toyota   Blue          32549      3   $7,000.00    7.0              8.9
# 3     BMW  Black          11179      5  $22,000.00    4.0              7.0
# 4  Nissan  White         213095      4   $3,500.00    4.0              9.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              6.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              7.8
# 7   Honda   Blue          54738      4   $7,000.00    5.0              9.9
# 8  Toyota  White          60000      4   $6,250.00    5.0             10.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.0

# %%
#COLUMN FROM ANOTHER COLUMN
car_sale["Total fuel used (L)"]=(car_sale["Odometer (KM)"]/100) * car_sale["Fuel per 100 km"]

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuel per 100 km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0              5.6
# 1   Honda    Red          87899      4   $5,000.00    6.0              7.9
# 2  Toyota   Blue          32549      3   $7,000.00    7.0              8.9
# 3     BMW  Black          11179      5  $22,000.00    4.0              7.0
# 4  Nissan  White         213095      4   $3,500.00    4.0              9.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              6.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              7.8
# 7   Honda   Blue          54738      4   $7,000.00    5.0              9.9
# 8  Toyota  White          60000      4   $6,250.00    5.0             10.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.0
#
#    Total fuel used (L)
# 0             8402.408
# 1             6944.021
# 2             2896.861
# 3              782.530
# ...

# %%
#COLUMN FROM CONSTANT VALUE
car_sale["No of wheels"]=4

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuel per 100 km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0              5.6
# 1   Honda    Red          87899      4   $5,000.00    6.0              7.9
# 2  Toyota   Blue          32549      3   $7,000.00    7.0              8.9
# 3     BMW  Black          11179      5  $22,000.00    4.0              7.0
# 4  Nissan  White         213095      4   $3,500.00    4.0              9.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              6.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              7.8
# 7   Honda   Blue          54738      4   $7,000.00    5.0              9.9
# 8  Toyota  White          60000      4   $6,250.00    5.0             10.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.0
#
#    Total fuel used (L)  No of wheels
# 0             8402.408             4
# 1             6944.021             4
# ...

# %%
car_sale_shuffled=car_sale.sample(frac=1)

# %%
car_sale_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuel per 100 km  \
# 2  Toyota   Blue          32549      3   $7,000.00    7.0              8.9
# 1   Honda    Red          87899      4   $5,000.00    6.0              7.9
# 5  Toyota  Green          99213      4   $4,500.00    5.0              6.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              7.8
# 3     BMW  Black          11179      5  $22,000.00    4.0              7.0
# 8  Toyota  White          60000      4   $6,250.00    5.0             10.0
# 0  Toyota  White         150043      4   $4,000.00    5.0              5.6
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.0
# 4  Nissan  White         213095      4   $3,500.00    4.0              9.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              9.9
#
#    Total fuel used (L)  No of wheels
# 2             2896.861             4
# 1             6944.021             4
# ...

# %%
car_sale_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sale_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuel per 100 km  \
# 0  Toyota   Blue          32549      3   $7,000.00    7.0              8.9
# 1   Honda    Red          87899      4   $5,000.00    6.0              7.9
# 2  Toyota  Green          99213      4   $4,500.00    5.0              6.0
# 3   Honda   Blue          45698      4   $7,500.00    5.0              7.8
# 4     BMW  Black          11179      5  $22,000.00    4.0              7.0
# 5  Toyota  White          60000      4   $6,250.00    5.0             10.0
# 6  Toyota  White         150043      4   $4,000.00    5.0              5.6
# 7  Nissan  White          31600      4   $9,700.00    5.0              9.0
# 8  Nissan  White         213095      4   $3,500.00    4.0              9.0
# 9   Honda   Blue          54738      4   $7,000.00    5.0              9.9
#
#    Total fuel used (L)  No of wheels
# 0             2896.861             4
# 1             6944.021             4
# ...

# %%
car_sale["Odometer (KM)"]=car_sale["Odometer (KM)"].apply(lambda x : x/1.6)

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuel per 100 km  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0              5.6
# 1   Honda    Red      54936.875      4   $5,000.00    6.0              7.9
# 2  Toyota   Blue      20343.125      3   $7,000.00    7.0              8.9
# 3     BMW  Black       6986.875      5  $22,000.00    4.0              7.0
# 4  Nissan  White     133184.375      4   $3,500.00    4.0              9.0
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0              6.0
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0              7.8
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0              9.9
# 8  Toyota  White      37500.000      4   $6,250.00    5.0             10.0
# 9  Nissan  White      19750.000      4   $9,700.00    5.0              9.0
#
#    Total fuel used (L)  No of wheels
# 0             8402.408             4
# 1             6944.021             4
# ...
